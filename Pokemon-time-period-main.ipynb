# %%
#The project consists on samples of Pokemon captured during the day period (6am-6pm, Lisbon, Portugal) and the night period (6pm-6am, Lisbon, Portugal) 
#With the samples I'm gonna analyse if the period of the day (day or night) might influence on the Pokemon's stats, perfection (Attack, Defense, Stamina, Level and Perfection)
#Each Pokemon has a percentage of perfection that influences on their status potential 
#Therefore the more perfect the Pokemon, higher will be their status when they level up till the max level
#Egg: 2 Pokemons from the same species, both max level, will have different stats because the one that is more perfect will have better attributes
#All the Pokemons and data comes from Pokemon Go (which is the game I'm using as base for this)
#To have access to the attributes and the perfection rate I'm using Poke Genie that is an app to calculate their stats numerically since on Pokemon Go you don't have access to the numerical part

# %%
#First we import the necessary libraries to import the data
#All the data collect was manully aquired by your one and only Pokemon master, Tina the Tuna

# %%
import pandas as pd

# %%
pokemon_data = pd.read_excel("Pokemon-time-period-stats.xlsx")

pokemon_data
# Out:
#      Pokemon           Type  Level   CP  Attack  Defense  Stamina  \
# 0    Dratini         Dragon     10  249       3        6       14
# 1    Dratini         Dragon     25  595       3        7        1
# 2    Dratini         Dragon     27  745      14       10       13
# 3      Deino    Dark/Dragon     15  385       1        4       15
# 4      Ralts  Psychic/Fairy     20  274      11       11        5
# ..       ...            ...    ...  ...     ...      ...      ...
# 116    Ralts  Psychic/Fairy     29  388      10        8        7
# 117    Deino    Dark/Dragon     15  423       8       15       10
# 118  Dratini         Dragon     14  371       8       15        8
# 119  Dratini         Dragon      8  202       5       15        6
# 120  Vibrava  Ground/Dragon      8  254       4       15       13
#
#      Perfection % Time Period
# 0              51         Day
# 1              24         Day
# 2              82         Day
# 3              44         Day
# 4              60         Day
# ..            ...         ...
# 116            56       Night
# 117            73       Night
# 118            69       Night
# 119            58       Night
# 120            71       Night
#
# [121 rows x 9 columns]

# %%
#It's known that the Pokemon CP (combat power) is calculated using Attack, Defense, Stamina and Perfection
#Perfection influences on a Pokemon IV (individual value), each species of Pokemon has a max IV
#A Pokemon only has their IV's on max if they are "perfect"
#more about Pokemon Go and CP, etc -> https://gamepress.gg/pokemongo/pokemon-stats-advanced#:~:text=Calculating%20CP,*%20CP_Multiplier%5E2)%20%2F%2010

# %%
#We want to test the hypotesis that the time period (day or night) might influence on the chance of capturing a more perfect Pokemon

#Therefore:
## H0 -> mu_day = mu_night
## H1 -> mu_day != mu_night

##Significance level -> 5%

# %%
#As you can see, me, tuna, collected data of 121 Pokemons
#Therefore we shall run an AB test to check if the time period influences on the Pokemon perfection

# %%
import scipy.stats as st

# %%
pokemon_day = pokemon_data[pokemon_data["Time Period"]=="Day"]
pokemon_day.reset_index()
# Out:
#     index   Pokemon           Type  Level   CP  Attack  Defense  Stamina  \
# 0       0   Dratini         Dragon     10  249       3        6       14
# 1       1   Dratini         Dragon     25  595       3        7        1
# 2       2   Dratini         Dragon     27  745      14       10       13
# 3       3     Deino    Dark/Dragon     15  385       1        4       15
# 4       4     Ralts  Psychic/Fairy     20  274      11       11        5
# ..    ...       ...            ...    ...  ...     ...      ...      ...
# 61     61  Deerling   Normal/Grass      6  177      14        7       12
# 62     62  Magikarp          Water      9   63      14        7        9
# 63     63     Ralts  Psychic/Fairy     25  301       6        5        0
# 64     64  Snubbull          Fairy     15  502      12       10       12
# 65     65  Clefairy          Fairy     14  448      15       11       10
#
#     Perfection % Time Period
# 0             51         Day
# 1             24         Day
# 2             82         Day
# 3             44         Day
# 4             60         Day
# ..           ...         ...
# 61            73         Day
# 62            67         Day
# 63            24         Day
# 64            76         Day
# 65            80         Day
#
# [66 rows x 10 columns]

# %%
pokemon_night = pokemon_data[pokemon_data["Time Period"]=="Night"]
pokemon_night.reset_index()
# Out:
#     index     Pokemon            Type  Level    CP  Attack  Defense  Stamina  \
# 0      66     Dratini          Dragon     15   408      11       14       10
# 1      67    Clefairy           Fairy      7   211      15        4        9
# 2      68     Slakoth          Normal     20   535       9       13       13
# 3      69     Vibrava   Ground/Dragon     10   299       2        2       14
# 4      70       Deino     Dark/Dragon     13   362      10        9       10
# 5      71       Ralts   Psychic/Fairy     10   127       4       10        9
# 6      72    Ducklett    Water/Flying     25   509       5        2       10
# 7      73      Marill     Water/Fairy      6    70      14        4       11
# 8      74  Jigglypuff    Normal/Fairy     13   217       6        4       13
# 9      75     Dedenne  Electric/Fairy     21  1042      14        8        5
# 10     76     Yungoos          Normal      8   172       3        9       14
# 11     77      Weedle      Bug/Poison      8    89       9       12        6
# 12     78     Vibrava   Ground/Dragon     22   656       1       13        0
# 13     79       Eevee          Normal      1    13       5       10        6
# 14     80     Dratini          Dragon     25   690      15       10       11
# 15     81       Deino     Dark/Dragon     15   428      10       13       11
# 16     82       Bagon          Dragon     12   358      10        2       14
# 17     83     Dratini          Dragon     17   424       9        3        6
# 18     84     Dratini          Dragon      5   126      13       15        2
# 19     85       Deino     Dark/Dragon     17   435       4        0       13
# 20     86     Togetic    Fairy/Flying     13   587       4       14       15
# 21     87       Bagon          Dragon     30   928      13        5       14
# 22     88     Dratini          Dragon     22   534       1       12        4
# 23     89     Dratini          Dragon     28   704       1       12       13
# 24     90     Dratini          Dragon      6   149      11        9        4
# 25     91       Bagon          Dragon     10   302      13        2       12
# 26     92     Dratini          Dragon     30   805      15        9        5
# 27     93     Dratini          Dragon      1    11       0        8        7
# 28     94     Dratini          Dragon      3    66      12        5        3
# 29     95    Clefairy           Fairy     31   943      11       12        8
# 30     96    Clefairy           Fairy     31   953       9       14       15
# 31     97    Clefairy           Fairy     28   841       8        8       13
# 32     98      Noibat   Flying/Dragon      5    71       2        2       13
# 33     99      Noibat   Flying/Dragon     27   469      13        4       14
# 34    100     Dedenne  Electric/Fairy     32  1552      14        8        8
# 35    101   Bulbasaur    Grass/Poison     11   328      14        4       12
# 36    102      Gulpin          Poison     18   392      10        6        4
# 37    103    Clefairy           Fairy     14   409       4       15        5
# 38    104     Dratini          Dragon     22   532       2        5       10
# 39    105  Jigglypuff    Normal/Fairy     29   515       7        9       11
# 40    106      Marill     Water/Fairy     33   338       7       10       10
# 41    107    Clefairy           Fairy     25   772      10       11       12
# 42    108     Purugly          Normal      7   373      14       11       14
# 43    109       Deino     Dark/Dragon     16   428      10        6        2
# 44    110       Ralts   Psychic/Fairy     12   171      11       11       14
# 45    111       Deino     Dark/Dragon      1    14       9       15       11
# 46    112  Jigglypuff    Normal/Fairy     13   234       5       13       10
# 47    113  Jigglypuff    Normal/Fairy     14   259       6       14       14
# 48    114       Goomy          Dragon     16   395      11        3        5
# 49    115      Gulpin          Poison      6   134      12       12       10
# 50    116       Ralts   Psychic/Fairy     29   388      10        8        7
# 51    117       Deino     Dark/Dragon     15   423       8       15       10
# 52    118     Dratini          Dragon     14   371       8       15        8
# 53    119     Dratini          Dragon      8   202       5       15        6
# 54    120     Vibrava   Ground/Dragon      8   254       4       15       13
#
#     Perfection % Time Period
# 0             78       Night
# 1             62       Night
# 2             78       Night
# 3             40       Night
# 4             64       Night
# 5             51       Night
# 6             38       Night
# 7             64       Night
# 8             51       Night
# 9             60       Night
# 10            58       Night
# 11            60       Night
# 12            31       Night
# 13            47       Night
# 14            80       Night
# 15            76       Night
# 16            58       Night
# 17            40       Night
# 18            67       Night
# 19            38       Night
# 20            73       Night
# 21            71       Night
# 22            38       Night
# 23            58       Night
# 24            53       Night
# 25            60       Night
# 26            64       Night
# 27            33       Night
# 28            44       Night
# 29            69       Night
# 30            84       Night
# 31            64       Night
# 32            38       Night
# 33            69       Night
# 34            67       Night
# 35            67       Night
# 36            44       Night
# 37            53       Night
# 38            38       Night
# 39            60       Night
# 40            60       Night
# 41            73       Night
# 42            87       Night
# 43            40       Night
# 44            80       Night
# 45            78       Night
# 46            62       Night
# 47            76       Night
# 48            42       Night
# 49            76       Night
# 50            56       Night
# 51            73       Night
# 52            69       Night
# 53            58       Night
# 54            71       Night

# %%
pokemon_perfection_ab_test = st.ttest_ind(pokemon_day["Perfection %"],pokemon_night["Perfection %"], equal_var=False)

# %%
pokemon_perfection_ab_test
# Out:
# Ttest_indResult(statistic=-0.9858108695018762, pvalue=0.3262264231778519)

# %%
#Since our p-value is higher than our significance level we cannot discard the null hypotesis
#Therefore the period of the day most likely does not influence on a Pokemon status perfection

# %%
#So we noticed that the time period doesnt influence on the perfection rate but could influence individually on any of the other attributes?
#Let's run some more AB tests and compare with each status: Attack, Defense and Stamina

# %%
#First, we attack cause we aggressive and ppl like it (;

#H0 -> attack_day = attack_night
#H1 -> attack_day != attack_night
#sig -> 5%

# %%
pokemon_attack_ab_test = st.ttest_ind(pokemon_day["Attack"],pokemon_night["Attack"])
pokemon_attack_ab_test
# Out:
# Ttest_indResult(statistic=-0.2812943942777729, pvalue=0.7789731440143236)

# %%
#As you can see, again, we cannot reject the null hypotesis

# %%
#Second, we defense cause we cry babies that need protection

#H0 -> defense_day = defense_night
#H1 -> defense_day != defense_night
#sig -> 5%

# %%
pokemon_defense_ab_test = st.ttest_ind(pokemon_day["Defense"],pokemon_night["Defense"])
pokemon_defense_ab_test
# Out:
# Ttest_indResult(statistic=-0.05664166141557965, pvalue=0.9549256419175032)

# %%
#As you can see, again, we cannot reject the null hypotesis

# %%
#Third, stamina high so we can get fried <3

#H0 -> stamina_day = stamina_night
#H1 -> stamina_day != stamina_night
#sig -> 5%

# %%
pokemon_stamina_ab_test = st.ttest_ind(pokemon_day["Stamina"],pokemon_night["Stamina"])
pokemon_stamina_ab_test
# Out:
# Ttest_indResult(statistic=-1.3156448797013307, pvalue=0.19082234636525847)

# %%
#As you can see, again, we cannot reject the null hypotesis

# %%
#Therefore, even analysing the status individually we cannot assume that the time period influence on any

# %%
#Now lets run some more data cause why not

# %%
pokemon_day.mean()
# Out:
# C:\Users\betti\AppData\Local\Temp\ipykernel_2584\1438833859.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon_day.mean()
# Level            15.848485
# CP              389.212121
# Attack            8.196970
# Defense           8.939394
# Stamina           8.469697
# Perfection %     56.893939
# dtype: float64

# %%
pokemon_night.mean()
# Out:
# C:\Users\betti\AppData\Local\Temp\ipykernel_2584\828154611.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon_night.mean()
# Level            15.963636
# CP              418.509091
# Attack            8.418182
# Defense           8.981818
# Stamina           9.509091
# Perfection %     59.800000
# dtype: float64
